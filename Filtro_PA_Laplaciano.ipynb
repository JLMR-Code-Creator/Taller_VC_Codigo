# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('Archivo "{name}" tamaño {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f84859e8-d332-4730-b485-a28720033679" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f84859e8-d332-4730-b485-a28720033679">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Fig0333.tif to Fig0333.tif
# Archivo "Fig0333.tif" tamaño 250415 bytes

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

img = cv.imread('Fig0333.tif', cv.IMREAD_GRAYSCALE)

laplacian = np.array((
	[0, 1, 0],
	[1, -4, 1],
	[0, 1, 0]), dtype="int")
#display(laplacian)

# %%
outputLaplaciano = cv.filter2D(img, -1, laplacian)

figure(figsize=(8, 6), dpi=200)
plt.subplot(1,2,1),plt.imshow(img, cmap='gray'), plt.title('Imagen original')
plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(outputLaplaciano, cmap='gray'), plt.title('Salida Filtro')
plt.xticks([]), plt.yticks([])
plt.show()
